# %% [markdown]
# ## Compare and contrast the following pairs of concepts from the chapter using you own words:
#
# 1.Hardware vs. Software
# 2.Algorithm vs. Program
# 3.Programming Language vs. Natural Language
# 4.High-Level Language vs. Machine Language
# 5.Interpreter vs. Compiler
# 6.Syntax vs. Semantics
#
# Programming Exercises
# 1, 2, 3, 4, 5, 6 and 7

# %% [markdown]
# ## Compare and contrast
# 1. A hardware is a physical element of a computer, while software is the programs an other operating systems.
#
# 2. A algorithm is a set of rules given to a computer to solve problem operations. A progrfam is where you write those instructions so the computer executes them.
#
# 3. A programming language is a language where the computer reads those set of instructions that produce the outputs, and implements the algorithm. Natural Language is a human language, where if given example an AI interpretate the language given.
#
# 4. High programmingv language is a language that enable a programmer to write programs of a particular type of computer, they are more of a human language than a computer one. Machine Language is a low lever language that are composed of binary digits.
#
# 5. Interpreter is a program that executes instructions, such as high level language. Compiler is a code that is written on high level language to machine language so the computer understand it.
#
# 6. A syntax is a set of rule that defines combinations of symbols that determine if the statements, and expressions are correct on the language written. A semantics it describes the processes a computer follows when executing a program on the language written.

# %% [markdown]
# ## 1. Start up an interactive Python session and try typing in each of the following commands. Write down the results you see.

# %%
print('Hello, world!')  
print('Hello', 'world!')  
print(3)  
print(3.0)  
print(2 + 3)  
print(2.0 + 3.0)  
print('2' + '3')  
print('2 + 3 =', 2 + 3)  
print(2 * 3)  
print(2 ** 3)  
print(7 / 3)  
print(7 // 3)
# Out:
# Hello, world!
# Hello world!
# 3
# 3.0
# 5
# 5.0
# 23
# 2 + 3 = 5
# 6
# 8
# 2.3333333333333335
# 2

# %% [markdown]
# ## 2. Enter and run the chaos program from Section 1.6. Try it out with various values of input to see that it functions as described in the chapter.

# %%
# File: chaos. py
# A simple program illustrating chaotic behavior.

def main() :
    print('This program illustrates a chaotic function')
    x = eval(input('Enter a number between 0 and 1: ') )
    for i in range(10) :
        x = 3.9 * x * (1 - x)
        print(x)
main()
# Out:
# This program illustrates a chaotic function
# 0.03861
# 0.14476514481
# 0.482851970866745
# 0.9738531858776958
# 0.09930631711087586
# 0.348833832721725
# 0.8858802804945467
# 0.3942759955892548
# 0.9314074960762914
# 0.24916153208382014

# %% [markdown]
# ## 3. Modify the chaos program using 2.0 in place of 3.9 as the multiplier in the logistic function. Your modified line of code should look like this:
#  X = 2. 0 * X * (1 - X)
#
#   Run the program for various input values and compare the results to those obtained from the original program. Write a short paragraph describing any differences that you notice in the behavior of the two versions.

# %%
# File: chaos. py
# A simple program illustrating chaotic behavior.

def main() :
    print('This program illustrates a chaotic function')
    x = eval(input('Enter a number between 0 and 1: ') )
    for i in range(10) :
        x = 2.0 * x * (1 - x) 
        print(x)
main()
# Out:
# This program illustrates a chaotic function
# 0.0392
# 0.07532672
# 0.1393052105080832
# 0.23979853766676365
# 0.36459039799929077
# 0.463328479372019
# 0.4973103991496632
# 0.49998553209453167
# 0.49999999958135943
# 0.5

# %% [markdown]
# ## 4. Modify the chaos program so that it prints out 20 values instead of 10

# %%
# File: chaos. py
# A simple program illustrating chaotic behavior.

def main() :
    print('This program illustrates a chaotic function')
    x = eval(input('Enter a number between 0 and 1: ') )
    for i in range(20) :
        x = 3.9 * x * (1 - x)
        print(x)
main()
# Out:
# This program illustrates a chaotic function
# 0.03861
# 0.14476514481
# 0.482851970866745
# 0.9738531858776958
# 0.09930631711087586
# 0.348833832721725
# 0.8858802804945467
# 0.3942759955892548
# 0.9314074960762914
# 0.24916153208382014
# 0.729612245752508
# 0.7693850447419105
# 0.6919836209106557
# 0.8312549282779312
# 0.5470536727171723
# 0.9663652123469184
# 0.12676360597919342
# 0.43170891729554633
# 0.9568116792899085
# 0.1611600496909017

# %% [markdown]
# ## 5. Modify the chaos program so that the number of values to print is determined by the user. You will have to add a line near the top of the program to get another value from the user:
#
# n = eval(input("How many numbers should I print? ") )
#
# Then you will need to change the loop to use n instead of a specific number.

# %%
# File: chaos. py
# A simple program illustrating chaotic behavior.

def main() :
    print('This program illustrates a chaotic function')
    x = eval(input('Enter a number between 0 and 1: ') )
    n = eval(input('How many numbers should I print? ') )
    for i in range(n) :
        x = 3.9 * x * (1 - x)
        print(x)
main()
# Out:
# This program illustrates a chaotic function
# 0.03861
# 0.14476514481
# 0.482851970866745
# 0.9738531858776958
# 0.09930631711087586
# 0.348833832721725
# 0.8858802804945467
# 0.3942759955892548
# 0.9314074960762914
# 0.24916153208382014

# %% [markdown]
# ## 6. The calculation performed in the chaos program can be written in a number of ways that are algebraically equivalent. Write a version of the program for each of the following ways of doing the computation. Have your modified programs print out 100 iterations of the calculation and compare the results when run on the same input.
#
# a) 3 . 9 * x * ( 1 - x)
# b) 3.9 * (x - x * x)
# C) 3.9 * X - 3.9 * X * X
#
# Explain the results of this experiment. Hint: See discussion question number 4, above.

# %%
# File: chaos. py
# A simple program illustrating chaotic behavior.

def main() :
    print('This program illustrates a chaotic function')
    x = eval(input('Enter a number between 0 and 1: ') )
    n = 100
    for i in range(n) :
        x = 3.9 * x * ( 1 - x)
        print(x)
main()
# Out:
# This program illustrates a chaotic function
# 0.03861
# 0.14476514481
# 0.482851970866745
# 0.9738531858776958
# 0.09930631711087586
# 0.348833832721725
# 0.8858802804945467
# 0.3942759955892548
# 0.9314074960762914
# 0.24916153208382014
# 0.729612245752508
# 0.7693850447419105
# 0.6919836209106557
# 0.8312549282779312
# 0.5470536727171723
# 0.9663652123469184
# 0.12676360597919342
# 0.43170891729554633
# 0.9568116792899085
# 0.1611600496909017
# 0.5272312034906584
# 0.9721080000701564
# 0.10574474145205306
# 0.36879488531843696
# 0.9078623497374517
# 0.32622838429991396
# 0.8572333597502283
# 0.4772988740580995
# 0.9729901696357829
# 0.10249316776886197
# 0.35875444148530694
# 0.8971937995795023
# 0.3597246337448329
# 0.8982590043257169
# 0.35642008534660546
# 0.8946007516216833
# 0.3677319625964502
# 0.9067701484975113
# 0.32969838053611933
# 0.8618896977911205
# 0.4642398018673409
# 0.9700127120951006
# 0.11344339682913131
# 0.39223857092549824
# 0.9297111501749024
# 0.2548584769199138
# 0.7406319712817048
# 0.7491753921486152
# 0.732855333395577
# 0.7635357354660154
# 0.7041407729163068
# 0.8124735248492181
# 0.5942051554463899
# 0.9403890158805538
# 0.21862430729785362
# 0.6662281062699105
# 0.8672360450750854
# 0.44903698007067827
# 0.9648708053387659
# 0.13219102394038015
# 0.4473945728068986
# 0.964207409216342
# 0.13459477679174137
# 0.4542681891232785
# 0.9668435457483495
# 0.12502270479312388
# 0.42662890950940763
# 0.9540050640128632
# 0.17112966721763626
# 0.5531927864409075
# 0.9639650571355428
# 0.1354720604531287
# 0.4567655870298789
# 0.9677100635870032
# 0.12186445603582162
# 0.4173526905245682
# 0.9483607467222417
# 0.19099329911482796
# 0.6026079493514411
# 0.9339392740465791
# 0.24061715511571904
# 0.7126101051409746
# 0.7987080784485806
# 0.6270165870912707
# 0.912080467754374
# 0.3127397835718116
# 0.8382410842387454
# 0.5288125788386918
# 0.9717623576725903
# 0.10701708374447588
# 0.3727012673720845
# 0.9118006274181734
# 0.3136389487061952
# 0.8395512783866045
# 0.5253492244494882
# 0.9724939255972569
# 0.10432301206740609
# 0.36441491276030075
# 0.9033050680609924
# 0.3406455860976413

# %%
# File: chaos. py
# A simple program illustrating chaotic behavior.

def main() :
    print('This program illustrates a chaotic function')
    x = eval(input('Enter a number between 0 and 1: ') )
    n = 100
    for i in range(n) :
        x = 3.9 * (x - x * x)
        print(x)
main()
# Out:
# This program illustrates a chaotic function
# 0.038610000000000005
# 0.14476514481
# 0.4828519708667449
# 0.9738531858776956
# 0.09930631711087638
# 0.3488338327217267
# 0.8858802804945487
# 0.39427599558924864
# 0.9314074960762861
# 0.2491615320838378
# 0.7296122457525426
# 0.7693850447418484
# 0.6919836209107861
# 0.8312549282777357
# 0.5470536727176774
# 0.9663652123467331
# 0.12676360597986744
# 0.4317089172975086
# 0.9568116792909538
# 0.16116004968717743
# 0.5272312034808153
# 0.9721080000722471
# 0.10574474144435445
# 0.3687948852947622
# 0.907862349713223
# 0.32622838437699364
# 0.8572333598547035
# 0.47729887376698754
# 0.972990169584236
# 0.10249316795903503
# 0.3587544420749486
# 0.8971938002291198
# 0.35972463173224534
# 0.8982590021236486
# 0.35642009218715487
# 0.8946007592825741
# 0.3677319390171025
# 0.9067701241709156
# 0.3296984577197138
# 0.861889800318128
# 0.464239512460251
# 0.9700126313705859
# 0.11344369277318093
# 0.39223946323834374
# 0.929711900195675
# 0.25485596303786695
# 0.7406271644534426
# 0.7491844141356739
# 0.7328377982322576
# 0.7635675828859827
# 0.7040753040813985
# 0.8125777540299305
# 0.5939510759738565
# 0.940575461761083
# 0.21798372372663313
# 0.6648205976759256
# 0.8690532652688275
# 0.44381878083822385
# 0.9626903153926362
# 0.14007892096326535
# 0.46978158577362716
# 0.971438705022409
# 0.10820763488649669
# 0.3763450962911925
# 0.9153669126761856
# 0.30213427863003056
# 0.8223117095962923
# 0.5698491312427499
# 0.9559722855720689
# 0.16414817168171622
# 0.5350938427195375
# 0.9701968465923878
# 0.11276820927284065
# 0.3902010069759261
# 0.9279823064105076
# 0.2606414670582153
# 0.7515592215610306
# 0.7282000363856722
# 0.7719064992349538
# 0.6866607371277892
# 0.8391152999381504
# 0.5265031720566473
# 0.9722605692966494
# 0.10518282328165816
# 0.3670656481758148
# 0.9060809866098265
# 0.3318831060245608
# 0.8647731688441986
# 0.45606808763631074
# 0.9674729495966695
# 0.1227292614420196
# 0.4199004803288724
# 0.9499778610989731
# 0.1853277056310936
# 0.5888272539107725
# 0.9442279039544175
# 0.2053801204582328
# 0.6364765936572989
# 0.9023591435964319
# 0.34361776630094903

# %%
# File: chaos. py
# A simple program illustrating chaotic behavior.

def main() :
    print('This program illustrates a chaotic function')
    x = eval(input('Enter a number between 0 and 1: ') )
    n = 100
    for i in range(n) :
        x = 3.9 * x - 3.9 * x * x
        print(x)
main()
# Out:
# This program illustrates a chaotic function
# 0.03861
# 0.14476514481
# 0.482851970866745
# 0.9738531858776956
# 0.09930631711087612
# 0.3488338327217259
# 0.8858802804945477
# 0.39427599558925186
# 0.9314074960762888
# 0.24916153208382852
# 0.7296122457525244
# 0.7693850447418811
# 0.6919836209107175
# 0.8312549282778385
# 0.547053672717412
# 0.9663652123468305
# 0.1267636059795132
# 0.43170891729647726
# 0.9568116792904043
# 0.16116004968913522
# 0.5272312034859896
# 0.972108000071148
# 0.10574474144840185
# 0.3687948853072087
# 0.9078623497259608
# 0.32622838433647017
# 0.8572333597997772
# 0.4772988739200352
# 0.972990169611336
# 0.1024931678590546
# 0.358754441764954
# 0.8971937998875938
# 0.35972463279033073
# 0.8982590032813506
# 0.3564200885908462
# 0.8946007552549842
# 0.36773195141356485
# 0.906770136960232
# 0.3296984171416808
# 0.861889746416209
# 0.46423966461136645
# 0.9700126738102804
# 0.11344353718507261
# 0.3922389941184454
# 0.9297115058844426
# 0.2548572846710462
# 0.7406296915724753
# 0.7491796709815683
# 0.7328470171211174
# 0.7635508398094122
# 0.7041097238594389
# 0.8125229604414919
# 0.5940846568678544
# 0.9404775016340265
# 0.21832032516155975
# 0.6655605870533512
# 0.8680997988567438
# 0.44655989851833633
# 0.963862206659155
# 0.13584422760986747
# 0.4578232363962893
# 0.9680623703864751
# 0.1205787079699574
# 0.4135539843015872
# 0.9458556368424921
# 0.1997297292735256
# 0.6233672816196141
# 0.9156440039205687
# 0.30123624181902553
# 0.820922576891723
# 0.573333928600587
# 0.9540263261724158
# 0.17105437105527832
# 0.5529996154728298
# 0.9640450589629554
# 0.13518251468306186
# 0.45594198938739994
# 0.9674296776333541
# 0.12288703622355701
# 0.420364668951814
# 0.9502670347904988
# 0.18431242978578988
# 0.5863312962477678
# 0.9459329384239026
# 0.19946087627163323
# 0.6227373169234832
# 0.9162486490342554
# 0.2992745424909131
# 0.8178662337602942
# 0.5809481239966794
# 0.949444864763531
# 0.18719732279699652
# 0.593402492025071
# 0.9409763004856755
# 0.21660561939887213
# 0.661781737670442
# 0.8729240104896958
# 0.432617961361097
# 0.9572926773885749
# 0.15944528810647585

# %% [markdown]
# ## 7. (Advanced) Modify the chaos program so that it accepts two inputs and then prints a table with two columns similar to the one shown in Section 1.8. (Note: You will probably not be able to get the columns to line up as nicely as those in the example. Chapter 5 discusses how to print numbers with a fixed number of decimal places.)

# %%
# File: chaos. py
# A simple program illustrating chaotic behavior.

def main() :
    print('This program illustrates a chaotic function')
    n = eval(input('How many numbers should I print? ') )
    x = eval(input('Enter a number between 0 and 1: ') )
    y = eval(input('Enter a number between 0 and 1: ') )
    for i in range(n):
        x = 3.9 * x * (1 - x)
        y = 3.9 * y * (1 - y)
        print('{: < 20}'.format(x), '{: < 20}'.format(y))
main()
# Out:
# This program illustrates a chaotic function
#  0.03861              0.03861
#  0.14476514481        0.14476514481
#  0.482851970866745    0.482851970866745
#  0.9738531858776958   0.9738531858776958
#  0.09930631711087586  0.09930631711087586
#  0.348833832721725    0.348833832721725
#  0.8858802804945467   0.8858802804945467
#  0.3942759955892548   0.3942759955892548
#  0.9314074960762914   0.9314074960762914
#  0.24916153208382014  0.24916153208382014
